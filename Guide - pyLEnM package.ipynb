# %% [markdown]
# # Guide - pyLEnM package
# Welcome to the demonstration notebook where we'll go over all of the functions in the **pyLEnM** package!
# Let’s get started!

# %% [markdown]
# ## Installing, Importing, and Understanding the package

# %% [markdown]
# Make sure to install pyLEnM from https://pypi.org/project/pylenm/ by running `pip install pylenm` in your environment terminal. Once completed, you should be able to import the package.

# %%
# Import our packages
import pylenm
import pandas as pd

# %% [markdown]
# We can verify the package version by typing: `pylenm.__version__`

# %%
pylenm.__version__
# Out:
# '0.1.3'

# %% [markdown]
# The pyLEnM package has two modules as follows:
#    1. **functions:** where all of the package functionality is stored.
#    2. **usage:** where all of the fucntion descriptions are stored.
#
# Let's import each of these individually from the package:

# %%
from pylenm import functions, usage

# %% [markdown]
# Let's start with the **usage** module.
# The module has 2 useful functions to help you understand how to use the pyLEnM functions:
#    1. **get_FunctionList():** lists the fucntions available in the package.
#    2. **get_FunctionDescription():** provides a detailed description of a functions of functions.
#
# Let's see what pyLEnM has to offer:

# %%
usage.get_FunctionList()
# Out:
# pyLEnM functions:
#     1) simplify_data
#     2) get_MCL
#     3) get_unit
#     4) get_analyte_details
#     5) get_data_summary
#     6) query_data
#     7) plot_data
#     8) plot_all_data
#     9) plot_correlation_heatmap
#     10) plot_all_correlation_heatmap
#     11) interpolate_well_data
#     12) plot_corr_by_well
#     13) plot_all_corr_by_well
#     14) plot_corr_by_date
#     15) plot_corr_by_year
#     16) plot_MCL
#     17) plot_PCA_by_date
#     18) plot_PCA_by_year

# %% [markdown]
# You can run **get_FunctionDescription()** on its own to get ALL function descriptions: ...

# %%
usage.get_FunctionDescription()
# Out:
# --------------------------------------------------------------------------------------
# 1) simplify_data
# ------------------------------------------
#
# simplify_data (data=None, inplace=False, columns=None, save_csv=False,
#                    file_name='data_simplified', save_dir='data/')
# Description:
#     Removes all columns except 'COLLECTION_DATE', 'STATION_ID', 'ANALYTE_NAME', 'RESULT', and 'RESULT_UNITS'.
#     If the user specifies additional columns in addition to the ones listed above, those columns will be kept.
#     The function returns a dataframe and has an optional parameter to be able to save the dataframe to a csv file.
# Parameters:
#     data (dataframe): data to simplify
#     inplace (bool): save data to current working dataset
#     columns (list of strings): list of any additional columns on top of  ['COLLECTION_DATE', 'STATION_ID',
#         'ANALYTE_NAME', 'RESULT', and 'RESULT_UNITS'] to be kept in the dataframe.
#     save_csv (bool): flag to determine whether or not to save the dataframe to a csv file.
#     file_name (string): name of the csv file you want to save
#     save_dir (string): name of the directory you want to save the csv file to
#
# --------------------------------------------------------------------------------------
# 2) get_MCL
# ------------------------------------------
#
# get_MCL (analyte_name)
# Description:
#     Returns the Maximum Concentration Limit value for the specified analyte.
#     Example: 'TRITIUM' returns 1.3
# Parameters:
#     analyte_name (string): name of the analyte to be processed
#
# --------------------------------------------------------------------------------------
# 3) get_unit
# ------------------------------------------
#
# get_unit (analyte_name)
# Description:
#     Returns the unit of the analyte you specify.
#     Example: 'DEPTH_TO_WATER' returns 'ft'
# Parameters:
#     analyte_name (string): name of the analyte to be processed
#
# --------------------------------------------------------------------------------------
# 4) get_analyte_details
# ------------------------------------------
#
# Description:
#     Returns a csv file saved to save_dir with details pertaining to the specified analyte.
#     Details include the well names, the date ranges and the number of unique samples.
# Parameters:
#     analyte_name (string): name of the analyte to be processed
#     save_dir (string): name of the directory you want to save the csv file to
#
# --------------------------------------------------------------------------------------
# 5) get_data_summary
# ------------------------------------------
#
# get_data_summary (analytes=None, sort_by='date', ascending=False)
# Description:
#     Returns a dataframe with a summary of the data for certain analytes.
#     Summary includes the date ranges and the number of unique samples and other statistics for the analyte results.
# Parameters:
#     analytes (list of strings): list of analyte names to be processed.
#         If left empty, a list of all the analytes in the data will be used.
#     sort_by (string): {‘date’, ‘samples’, ‘wells’} sorts the data by either the dates by entering: ‘date’, the
#         samples by entering: ‘samples’, or by unique well locations by entering ‘wells’.
#     ascending (bool): flag to sort in ascending order.
#
# --------------------------------------------------------------------------------------
# 6) query_data
# ------------------------------------------
#
# query_data (well_name, analyte_name)
# Description:
#     Filters data by passing the data and specifying the well_name and analyte_name
# Parameters:
#     well_name (string): name of the well to be processed
#     analyte_name (string): name of the analyte to be processed
#
# --------------------------------------------------------------------------------------
# 7) plot_data
# ------------------------------------------
#
# plot_data (well_name, analyte_name, log_transform=True,
#      alpha=0, year_interval=2, plot_inline=True, save_dir='plot_data')
# Description:
#     Plot concentrations over time of a specified well and analyte with a smoothed curve on interpolated data points.
# Parameters:
#     well_name (string): name of the well to be processed
#     analyte_name (string): name of the analyte to be processed
#     log_transform (bool): choose whether or not the data should be transformed to log base 10 values
#     alpha (int): value between 0 and 10 for line smoothing
#     year_interval (int): plot by how many years to appear in the axis e.g.(1 = every year, 5 = every 5 years, ...)
#     plot_inline (bool): choose whether or not to show plot inline
#     save_dir (string): name of the directory you want to save the plot to
#
# --------------------------------------------------------------------------------------
# 8) plot_all_data
# ------------------------------------------
#
# plot_all_data (log_transform=True, alpha=0,
#             year_interval=2, plot_inline=True, save_dir='plot_data')
# Description:
#     Plot concentrations over time for every well and analyte with a smoothed curve on interpolated data points.
# Parameters:
#     log_transform (bool): choose whether or not the data should be transformed to log base 10 values
#     alpha (int): value between 0 and 10 for line smoothing
#     year_interval (int): plot by how many years to appear in the axis e.g.(1 = every year, 5 = every 5 years, ...)
#     plot_inline (bool): choose whether or not to show plot inline
#     save_dir (string): name of the directory you want to save the plot to
#
# --------------------------------------------------------------------------------------
# 9) plot_correlation_heatmap
# ------------------------------------------
#
# plot_correlation_heatmap (well_name, show_symmetry=True, color=True,
#      	          save_dir='plot_correlation_heatmap')
# Description:
#     Plots a heatmap of the correlations of the important analytes over time for a specified well.
# Parameters:
#     well_name (string): name of the well to be processed
#     show_symmetry (bool): choose whether or not the heatmap should show the same information twice over the diagonal
#     color (bool): choose whether or not the plot should be in color or in greyscale
#     save_dir (string): name of the directory you want to save the plot to
#
# --------------------------------------------------------------------------------------
# 10) plot_all_correlation_heatmap
# ------------------------------------------
#
# plot_all_correlation_heatmap (show_symmetry=True, color=True,
#     save_dir='plot_correlation_heatmap')
# Description:
#     Plots a heatmap of the correlations of the important analytes over time for each well in the dataset.
# Parameters:
#     show_symmetry (bool): choose whether or not the heatmap should show the same information twice over the diagonal
#     color (bool): choose whether or not the plot should be in color or in greyscale
#     save_dir (string): name of the directory you want to save the plot to
#
# --------------------------------------------------------------------------------------
# 11) interpolate_well_data
# ------------------------------------------
#
# interpolate_well_data (well_name, analytes, frequency='2W')
# Description:
#     Resamples the data based on the frequency specified and interpolates the values of the analytes.
# Parameters:
#     well_name (string): name of the well to be processed
#     analytes (list of strings): list of analyte names to use
#     frequency (string): {‘D’, ‘W’, ‘M’, ‘Y’} frequency to interpolate.
#         See https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html for valid frequency inputs.
#         (e.g. ‘W’ = every week, ‘D ’= every day, ‘2W’ = every 2 weeks)
#
# --------------------------------------------------------------------------------------
# 12) plot_corr_by_well
# ------------------------------------------
#
# plot_corr_by_well(well_name, interpolate=False, frequency='2W',
#         save_dir='plot_correlation')
# Description:
#     Plots the correlations with the physical plots as well as the correlations of the important analytes over time for a specified well.
# Parameters:
#     well_name (string): name of the well to be processed
#     interpolate (bool): choose whether or to interpolate the data
#     frequency (string): {‘D’, ‘W’, ‘M’, ‘Y’} frequency to interpolate.
#         See https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html for valid frequency inputs.
#         (e.g. ‘W’ = every week, ‘D ’= every day, ‘2W’ = every 2 weeks)
#     save_dir (string): name of the directory you want to save the plot to
#
# --------------------------------------------------------------------------------------
# 13) plot_all_corr_by_well
# ------------------------------------------
#
# plot_all_corr_by_well (well_name, interpolate=False, frequency='2W',
#                save_dir='plot_correlation')
# Description:
#     Plots the correlations with the physical plots as well as the important analytes over time for each well in the dataset.
# Parameters:
#     interpolate (bool): choose whether or to interpolate the data
#     frequency (string): {‘D’, ‘W’, ‘M’, ‘Y’} frequency to interpolate.
#     See https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html for valid frequency inputs.
#     (e.g. ‘W’ = every week, ‘D ’= every day, ‘2W’ = every 2 weeks)
#     save_dir (string): name of the directory you want to save the plot to
#
# --------------------------------------------------------------------------------------
# 14) plot_corr_by_date
# ------------------------------------------
#
# plot_corr_by_date (date, min_samples=48, save_dir=‘plot_corr_by_date’)
# Description:
#     Plots the correlations with the physical plots as well as the correlations of the important
#     analytes for ALL the wells on a specified date.
# Parameters:v
#     date (string): date to be analyzed
#     min_samples (int): minimum number of samples the result should contain in order to execute.
#     save_dir (string): name of the directory you want to save the plot to
#
# --------------------------------------------------------------------------------------
# 15) plot_corr_by_year
# ------------------------------------------
#
# plot_corr_by_year(year, min_samples=500, save_dir=‘plot_corr_by_year’)
# Description:
#     Plots the correlations with the physical plots as well as the correlations of the important
#     analytes for ALL the wells in specified year.
# Parameters:
#     year (int): year to be analyzed
#     min_samples (int): minimum number of samples the result should contain in order to execute.
#     save_dir (string): name of the directory you want to save the plot to
#
# --------------------------------------------------------------------------------------
# 16) plot_MCL
# ------------------------------------------
#
# plot_MCL (well_name, analyte_name, year_interval=5, save_dir=‘plot_MCL’)
# Description:
#     Plots the linear regression line of data given the analyte_name and well_name.
#     The plot includes the prediction where the line of best fit intersects with the
#     Maximum Concentration Limit (MCL).
# Parameters:
#     well_name (string): name of the well to be processed
#     analyte_name (string): name of the analyte to be processed
#     year_interval (int): plot by how many years to appear in the axis e.g.(1 = every year, 5 = every 5 years, ...)
#     save_dir (string): name of the directory you want to save the plot to
#
# --------------------------------------------------------------------------------------
# 17) plot_PCA_by_date
# ------------------------------------------
#
# plot_PCA_by_date (date, min_samples=48, show_labels=True,
#                         save_dir=‘plot_corr_by_date’)
# Description:
#     Gernates a PCA biplot (PCA score plot + loading plot) of the data given a date in the dataset.
#     Only uses the 6 important analytes.
# Parameters:
#     date (string): date to be analyzed
#     min_samples (int): minimum number of samples the result should contain in order to execute.
#     show_labels (bool): choose whether or not to show the name of the wells.
#     save_dir (string): name of the directory you want to save the plot to
#
# --------------------------------------------------------------------------------------
# 18) plot_PCA_by_year
# ------------------------------------------
#
# plot_PCA_by_year (year, min_samples=48, show_labels=True,
#                     save_dir=‘plot_corr_by_year’)
# Description:
#     Gernates a PCA biplot (PCA score plot + loading plot) of the data given a year in the dataset.
#     Only uses the 6 important analytes.
# Parameters:
#     year (int): date to be analyzed
#     min_samples (int): minimum number of samples the result should contain in order to execute.
#     show_labels (bool): choose whether or not to show the name of the wells.
#     save_dir (string): name of the directory you want to save the plot to
#
# --------------------------------------------------------------------------------------

# %% [markdown]
# ... or simply specify the name (as a string) of the function you would like a description for:

# %%
usage.get_FunctionDescription('simplify_data')
# Out:
# simplify_data (data=None, inplace=False, columns=None, save_csv=False,
#                    file_name='data_simplified', save_dir='data/')
# Description:
#     Removes all columns except 'COLLECTION_DATE', 'STATION_ID', 'ANALYTE_NAME', 'RESULT', and 'RESULT_UNITS'.
#     If the user specifies additional columns in addition to the ones listed above, those columns will be kept.
#     The function returns a dataframe and has an optional parameter to be able to save the dataframe to a csv file.
# Parameters:
#     data (dataframe): data to simplify
#     inplace (bool): save data to current working dataset
#     columns (list of strings): list of any additional columns on top of  ['COLLECTION_DATE', 'STATION_ID',
#         'ANALYTE_NAME', 'RESULT', and 'RESULT_UNITS'] to be kept in the dataframe.
#     save_csv (bool): flag to determine whether or not to save the dataframe to a csv file.
#     file_name (string): name of the csv file you want to save
#     save_dir (string): name of the directory you want to save the csv file to

# %% [markdown]
# If at any point you forget what or how to use any of the pyLEnM fucntions, refer back to the usage module!

# %% [markdown]
# ## Using pyLEnM

# %% [markdown]
# Now let's get our hands dirty and start exploring the **functions** module.
#
# First, import the dataset here. It's located in the same directory in a folder called `data`.

# %%
data = pd.read_csv('data/FASB_Data_thru_3Q2015.csv')
data
# Out:
#             ID FACILITY  FFA_INDEX_NO SRS_AREA  \
# 0       214782      SRS            19      GSA
# 1       214785      SRS            19      GSA
# 2       214786      SRS            19      GSA
# 3       214787      SRS            19      GSA
# 4       214788      SRS            19      GSA
# ...        ...      ...           ...      ...
# 660750  785623      SRS            19      GSA
# 660751  785624      SRS            19      GSA
# 660752  785625      SRS            19      GSA
# 660753  785626      SRS            19      GSA
# 660754  785627      SRS            19      GSA
#
#                                             OPERABLE_UNIT STATION_ID  \
# 0       F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FSB104D
# 1       F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FSB112A
# 2       F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FSB 97A
# 3       F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FSB 88C
# 4       F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FSB 97D
# ...                                                   ...        ...
# 660750  F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FBI 14D
# 660751  F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FBI 17D
# 660752  F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FSB117D
# 660753  F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FBI 15D
# 660754  F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...     FSB 79
#
#            STATION_TYPE  SEIR_ID              WELL_USE  REVISION_ID  \
# 0       MONITORING WELL      NaN  F_PLUME;H_AUX;MW_AUX          NaN
# 1       MONITORING WELL      NaN  F_PLUME;H_AUX;MW_AUX          NaN
# 2       MONITORING WELL      NaN    F_POC;H_AUX;MW_AUX          NaN
# 3       MONITORING WELL      NaN    F_POC;H_AUX;MW_AUX          NaN
# 4       MONITORING WELL      NaN    F_POC;H_AUX;MW_AUX          NaN
# ...                 ...      ...                   ...          ...
# 660750  MONITORING WELL      NaN                   NaN          NaN
# 660751  MONITORING WELL      NaN                   NaN          NaN
# 660752  MONITORING WELL      NaN  F_PLUME;H_AUX;MW_AUX          NaN
# 660753  MONITORING WELL      NaN                   NaN          NaN
# 660754  MONITORING WELL      NaN  F_PLUME;H_AUX;MW_AUX          NaN
#
#          SAMPLE_EVENT  LOG_BOOK_NO       SAMPLE_NAME COLLECTION_DATE  QUARTER  \
# 0          3Q02FHRCRA          NaN     FHR-000001046          9/5/02  2002-3Q
# 1          1Q00FHRCRA          NaN  FSB112A:129991:D         1/11/00  2000-1Q
# 2          1Q00FHRCRA          NaN     FSB97A:129830          1/3/00  2000-1Q
# 3             1Q97FSB          NaN      FSB88C:95040          1/3/97  1997-1Q
# 4             3Q95FSB          NaN      FSB97D:67314         8/18/95  1995-3Q
# ...               ...          ...               ...             ...      ...
# 660750  3Q15FSIFIELD4          NaN               NaN         9/24/15  2015-3Q
# 660751  3Q15FSIFIELD4          NaN               NaN         9/24/15  2015-3Q
# 660752  3Q15FSIFIELD4          NaN               NaN         9/24/15  2015-3Q
# 660753  3Q15FSIFIELD4          NaN               NaN         9/24/15  2015-3Q
# 660754  3Q15FSIFIELD4          NaN               NaN         9/24/15  2015-3Q
#
#        SAMPLE_USE             ANALYTE_NAME ANALYTICAL_METHOD      CAS_No  \
# 0          FA;PWI  CIS-1,3-DICHLOROPROPENE          EPA8260B  10061-01-5
# 1             NaN  CIS-1,3-DICHLOROPROPENE          EPA8260B  10061-01-5
# 2             NaN  CIS-1,3-DICHLOROPROPENE          EPA8260B  10061-01-5
# 3             NaN  CIS-1,3-DICHLOROPROPENE           EPA8260  10061-01-5
# 4             NaN  CIS-1,3-DICHLOROPROPENE           EPA8240  10061-01-5
# ...           ...                      ...               ...         ...
# 660750        NaN           DEPTH_TO_WATER               NaN    H20DEPTH
# 660751        NaN           DEPTH_TO_WATER               NaN    H20DEPTH
# 660752        NaN           DEPTH_TO_WATER               NaN    H20DEPTH
# 660753        NaN           DEPTH_TO_WATER               NaN    H20DEPTH
# 660754        NaN           DEPTH_TO_WATER               NaN    H20DEPTH
#
#        FILTERED_UNFILTERED   MDL  PQL EPA_STORET___EMS_QUALIFIERS  \
# 0                        U  0.08  1.0                         NaN
# 1                        U  0.96  5.0                         NaN
# 2                        U  0.54  1.0                         NaN
# 3                        U   NaN  2.0                         NaN
# 4                        U   NaN  2.0                         NaN
# ...                    ...   ...  ...                         ...
# 660750                 NaN   NaN  NaN                         NaN
# 660751                 NaN   NaN  NaN                         NaN
# 660752                 NaN   NaN  NaN                         NaN
# 660753                 NaN   NaN  NaN                         NaN
# 660754                 NaN   NaN  NaN                         NaN
#
#        EPA_FUNCT_GUIDE_CODE LAB_QUALIFICATION DATA_QUALIFERS  RESULT  \
# 0                       NaN                 U              U    1.00
# 1                         U               NaN              U    5.00
# 2                         U               NaN              U    1.00
# 3                         U               NaN              U    2.00
# 4                         U               NaN              U    2.00
# ...                     ...               ...            ...     ...
# 660750                  NaN               NaN            NaN   17.40
# 660751                  NaN               NaN            NaN   25.16
# 660752                  NaN               NaN            NaN   23.46
# 660753                  NaN               NaN            NaN   15.40
# 660754                  NaN               NaN            NaN   19.76
#
#        RESULT_UNITS  COUNTING_UNCERTAINTY MATRIX_CODE VALIDATION_STATUS  \
# 0              ug/L                   NaN     GRWATER                VU
# 1              ug/L                   NaN     GRWATER                 D
# 2              ug/L                   NaN     GRWATER                 D
# 3              ug/L                   NaN     GRWATER                 D
# 4              ug/L                   NaN     GRWATER                 D
# ...             ...                   ...         ...               ...
# 660750           ft                   NaN         NaN                UE
# 660751           ft                   NaN         NaN                UE
# 660752           ft                   NaN         NaN                UE
# 660753           ft                   NaN         NaN                UE
# 660754           ft                   NaN         NaN                UE
#
#        FIELD_QC_CODE LAB_QC_CODE LAB_CODE ANALYTE_TYPE  DILUTION_FACTOR  \
# 0                REG         REG   MLFY02          TRG              1.0
# 1                SPL         REG       WA          TRG              1.0
# 2                REG         REG       ML          TRG              1.0
# 3                REG         REG       GE          TRG              1.0
# 4                REG         REG       GE          TRG              1.0
# ...              ...         ...      ...          ...              ...
# 660750           NaN         NaN      NaN          NaN              NaN
# 660751           NaN         NaN      NaN          NaN              NaN
# 660752           NaN         NaN      NaN          NaN              NaN
# 660753           NaN         NaN      NaN          NaN              NaN
# 660754           NaN         NaN      NaN          NaN              NaN
#
#        SAMPLER_COMMENTS
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 660750      PROG_NAME=W
# 660751      PROG_NAME=W
# 660752      PROG_NAME=W
# 660753      PROG_NAME=W
# 660754      PROG_NAME=W
#
# [660755 rows x 37 columns]

# %% [markdown]
# Now that we have our data imported let's save the data into our functions class.
#
# We do this by initializing **functions** with our data. We'll call the instance pylenm

# %%
# Create instance
pylenm = functions(data)
# Out:
# Successfully stored the data!

# %% [markdown]
# If the data passed doesn't meet the package requiremnts, you'll be presented with the following message.
#
# To demonstrate the requirments we'll pass an arbitrary list instead of a dataframe.

# %%
functions([1,2,3,4,5])
# Out:
# ERROR: Make sure the data is a pandas DataFrame.
#
# PYLENM REQUIREMENTS:
# The imported data needs to meet ALL of the following conditions to have a successful import:
#    1) Data should be a pandas dataframe.
#    2) Data must contain these column names (Case sensitive):
#       ['COLLECTION_DATE','STATION_ID','ANALYTE_NAME','RESULT','RESULT_UNITS']

# %% [markdown]
# We can view the data we imported by running the `getData()` function.

# %%
pylenm.getData()
# Out:
#             ID FACILITY  FFA_INDEX_NO SRS_AREA  \
# 0       214782      SRS            19      GSA
# 1       214785      SRS            19      GSA
# 2       214786      SRS            19      GSA
# 3       214787      SRS            19      GSA
# 4       214788      SRS            19      GSA
# ...        ...      ...           ...      ...
# 660750  785623      SRS            19      GSA
# 660751  785624      SRS            19      GSA
# 660752  785625      SRS            19      GSA
# 660753  785626      SRS            19      GSA
# 660754  785627      SRS            19      GSA
#
#                                             OPERABLE_UNIT STATION_ID  \
# 0       F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FSB104D
# 1       F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FSB112A
# 2       F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FSB 97A
# 3       F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FSB 88C
# 4       F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FSB 97D
# ...                                                   ...        ...
# 660750  F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FBI 14D
# 660751  F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FBI 17D
# 660752  F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FSB117D
# 660753  F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...    FBI 15D
# 660754  F & H-AREA HAZARDOUS WASTE MANAGEMENT FACILITI...     FSB 79
#
#            STATION_TYPE  SEIR_ID              WELL_USE  REVISION_ID  \
# 0       MONITORING WELL      NaN  F_PLUME;H_AUX;MW_AUX          NaN
# 1       MONITORING WELL      NaN  F_PLUME;H_AUX;MW_AUX          NaN
# 2       MONITORING WELL      NaN    F_POC;H_AUX;MW_AUX          NaN
# 3       MONITORING WELL      NaN    F_POC;H_AUX;MW_AUX          NaN
# 4       MONITORING WELL      NaN    F_POC;H_AUX;MW_AUX          NaN
# ...                 ...      ...                   ...          ...
# 660750  MONITORING WELL      NaN                   NaN          NaN
# 660751  MONITORING WELL      NaN                   NaN          NaN
# 660752  MONITORING WELL      NaN  F_PLUME;H_AUX;MW_AUX          NaN
# 660753  MONITORING WELL      NaN                   NaN          NaN
# 660754  MONITORING WELL      NaN  F_PLUME;H_AUX;MW_AUX          NaN
#
#          SAMPLE_EVENT  LOG_BOOK_NO       SAMPLE_NAME COLLECTION_DATE  QUARTER  \
# 0          3Q02FHRCRA          NaN     FHR-000001046          9/5/02  2002-3Q
# 1          1Q00FHRCRA          NaN  FSB112A:129991:D         1/11/00  2000-1Q
# 2          1Q00FHRCRA          NaN     FSB97A:129830          1/3/00  2000-1Q
# 3             1Q97FSB          NaN      FSB88C:95040          1/3/97  1997-1Q
# 4             3Q95FSB          NaN      FSB97D:67314         8/18/95  1995-3Q
# ...               ...          ...               ...             ...      ...
# 660750  3Q15FSIFIELD4          NaN               NaN         9/24/15  2015-3Q
# 660751  3Q15FSIFIELD4          NaN               NaN         9/24/15  2015-3Q
# 660752  3Q15FSIFIELD4          NaN               NaN         9/24/15  2015-3Q
# 660753  3Q15FSIFIELD4          NaN               NaN         9/24/15  2015-3Q
# 660754  3Q15FSIFIELD4          NaN               NaN         9/24/15  2015-3Q
#
#        SAMPLE_USE             ANALYTE_NAME ANALYTICAL_METHOD      CAS_No  \
# 0          FA;PWI  CIS-1,3-DICHLOROPROPENE          EPA8260B  10061-01-5
# 1             NaN  CIS-1,3-DICHLOROPROPENE          EPA8260B  10061-01-5
# 2             NaN  CIS-1,3-DICHLOROPROPENE          EPA8260B  10061-01-5
# 3             NaN  CIS-1,3-DICHLOROPROPENE           EPA8260  10061-01-5
# 4             NaN  CIS-1,3-DICHLOROPROPENE           EPA8240  10061-01-5
# ...           ...                      ...               ...         ...
# 660750        NaN           DEPTH_TO_WATER               NaN    H20DEPTH
# 660751        NaN           DEPTH_TO_WATER               NaN    H20DEPTH
# 660752        NaN           DEPTH_TO_WATER               NaN    H20DEPTH
# 660753        NaN           DEPTH_TO_WATER               NaN    H20DEPTH
# 660754        NaN           DEPTH_TO_WATER               NaN    H20DEPTH
#
#        FILTERED_UNFILTERED   MDL  PQL EPA_STORET___EMS_QUALIFIERS  \
# 0                        U  0.08  1.0                         NaN
# 1                        U  0.96  5.0                         NaN
# 2                        U  0.54  1.0                         NaN
# 3                        U   NaN  2.0                         NaN
# 4                        U   NaN  2.0                         NaN
# ...                    ...   ...  ...                         ...
# 660750                 NaN   NaN  NaN                         NaN
# 660751                 NaN   NaN  NaN                         NaN
# 660752                 NaN   NaN  NaN                         NaN
# 660753                 NaN   NaN  NaN                         NaN
# 660754                 NaN   NaN  NaN                         NaN
#
#        EPA_FUNCT_GUIDE_CODE LAB_QUALIFICATION DATA_QUALIFERS  RESULT  \
# 0                       NaN                 U              U    1.00
# 1                         U               NaN              U    5.00
# 2                         U               NaN              U    1.00
# 3                         U               NaN              U    2.00
# 4                         U               NaN              U    2.00
# ...                     ...               ...            ...     ...
# 660750                  NaN               NaN            NaN   17.40
# 660751                  NaN               NaN            NaN   25.16
# 660752                  NaN               NaN            NaN   23.46
# 660753                  NaN               NaN            NaN   15.40
# 660754                  NaN               NaN            NaN   19.76
#
#        RESULT_UNITS  COUNTING_UNCERTAINTY MATRIX_CODE VALIDATION_STATUS  \
# 0              ug/L                   NaN     GRWATER                VU
# 1              ug/L                   NaN     GRWATER                 D
# 2              ug/L                   NaN     GRWATER                 D
# 3              ug/L                   NaN     GRWATER                 D
# 4              ug/L                   NaN     GRWATER                 D
# ...             ...                   ...         ...               ...
# 660750           ft                   NaN         NaN                UE
# 660751           ft                   NaN         NaN                UE
# 660752           ft                   NaN         NaN                UE
# 660753           ft                   NaN         NaN                UE
# 660754           ft                   NaN         NaN                UE
#
#        FIELD_QC_CODE LAB_QC_CODE LAB_CODE ANALYTE_TYPE  DILUTION_FACTOR  \
# 0                REG         REG   MLFY02          TRG              1.0
# 1                SPL         REG       WA          TRG              1.0
# 2                REG         REG       ML          TRG              1.0
# 3                REG         REG       GE          TRG              1.0
# 4                REG         REG       GE          TRG              1.0
# ...              ...         ...      ...          ...              ...
# 660750           NaN         NaN      NaN          NaN              NaN
# 660751           NaN         NaN      NaN          NaN              NaN
# 660752           NaN         NaN      NaN          NaN              NaN
# 660753           NaN         NaN      NaN          NaN              NaN
# 660754           NaN         NaN      NaN          NaN              NaN
#
#        SAMPLER_COMMENTS
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 660750      PROG_NAME=W
# 660751      PROG_NAME=W
# 660752      PROG_NAME=W
# 660753      PROG_NAME=W
# 660754      PROG_NAME=W
#
# [660755 rows x 37 columns]

# %% [markdown]
# At any point we can also reset the current working dataset by running `setData()`

# %%
pylenm.setData(data)
# Out:
# Successfully stored the data!

# %% [markdown]
# Let's make use of the **simplify_data** function to get rid of columns we don't need for analysis.
#
# Just as a reminder, we'll call `usage.get_FunctionDescription('simplify_data')` to get details on how to use it.

# %%
usage.get_FunctionDescription('simplify_data')
# Out:
# simplify_data (data=None, inplace=False, columns=None, save_csv=False,
#                    file_name='data_simplified', save_dir='data/')
# Description:
#     Removes all columns except 'COLLECTION_DATE', 'STATION_ID', 'ANALYTE_NAME', 'RESULT', and 'RESULT_UNITS'.
#     If the user specifies additional columns in addition to the ones listed above, those columns will be kept.
#     The function returns a dataframe and has an optional parameter to be able to save the dataframe to a csv file.
# Parameters:
#     data (dataframe): data to simplify
#     inplace (bool): save data to current working dataset
#     columns (list of strings): list of any additional columns on top of  ['COLLECTION_DATE', 'STATION_ID',
#         'ANALYTE_NAME', 'RESULT', and 'RESULT_UNITS'] to be kept in the dataframe.
#     save_csv (bool): flag to determine whether or not to save the dataframe to a csv file.
#     file_name (string): name of the csv file you want to save
#     save_dir (string): name of the directory you want to save the csv file to

# %% [markdown]
# We'll set the `inplace` parameter to `True` to make it the default working dataset.

# %%
pylenm.simplify_data(inplace=True)
# Out:
# Successfully stored the data!
#        COLLECTION_DATE STATION_ID          ANALYTE_NAME  RESULT RESULT_UNITS
# 0           1990-01-01    FSB 93C  SPECIFIC CONDUCTANCE  345.00        uS/cm
# 1           1990-01-01    FSB111D               BENZENE    1.00         ug/L
# 2           1990-01-01    FSB 93C   1,2-DICHLOROPROPANE    1.00         ug/L
# 3           1990-01-01    FSB105C              FLUORIDE    2.50         mg/L
# 4           1990-01-01    FSB105C                BARIUM  559.00         ug/L
# ...                ...        ...                   ...     ...          ...
# 629770      2015-09-24    FOB 13D        DEPTH_TO_WATER   21.50           ft
# 629771      2015-09-24    FBI 14D        DEPTH_TO_WATER   17.40           ft
# 629772      2015-09-24    FBI 17D        DEPTH_TO_WATER   25.16           ft
# 629773      2015-09-24    FSB117D        DEPTH_TO_WATER   23.46           ft
# 629774      2015-09-24     FSB 79        DEPTH_TO_WATER   19.76           ft
#
# [629775 rows x 5 columns]

# %% [markdown]
# Let's generate some useful reports about the data by calling `get_analyte_details` and `get_data_summary`

# %%
pylenm.get_analyte_details('IODINE-129')
# Out:
#            Start Date    End Date  Date Range (days)  Unique samples  \
# Well Name
# FSB 87B    1990-01-06  2002-02-14               4422              15
# FSB 87A    1990-01-06  2006-01-23               5861              19
# FSB106C    1990-01-06  2006-01-26               5864              19
# FSB 78A    1990-01-06  2015-01-20               9145              27
# FSB 87C    1990-01-06  2015-01-20               9145              27
# ...               ...         ...                ...             ...
# FSB146D    2015-04-29  2015-09-09                133               9
# FSB145D    2015-04-30  2015-09-09                132               9
# FSB143D    2015-05-04  2015-09-09                128               9
# FSB144D    2015-05-04  2015-09-09                128               9
# FSB142D    2015-05-05  2015-09-09                127               9
#
#            Cumulative samples
# Well Name
# FSB 87B                    15
# FSB 87A                    34
# FSB106C                    53
# FSB 78A                    80
# FSB 87C                   107
# ...                       ...
# FSB146D                  4689
# FSB145D                  4698
# FSB143D                  4707
# FSB144D                  4716
# FSB142D                  4725
#
# [150 rows x 5 columns]

# %%
pylenm.get_data_summary(analytes=['TRITIUM','IODINE-129','SPECIFIC CONDUCTANCE',
                                        'PH','URANIUM-238', 'DEPTH_TO_WATER'],
                        sort_by='wells')
# Out:
#                      Start Date   End Date Date Range (days)  Unique wells  \
# Analyte Name
# TRITIUM              1990-01-01 2015-09-23         9396 days           160
# PH                   1990-01-01 2015-09-23         9396 days           158
# SPECIFIC CONDUCTANCE 1990-01-01 2015-09-23         9396 days           156
# DEPTH_TO_WATER       1990-01-01 2015-09-24         9397 days           155
# IODINE-129           1990-01-06 2015-09-23         9391 days           150
# URANIUM-238          1990-01-06 2015-09-23         9391 days           144
#
#                       Samples Result unit  Result mean   Result std  \
# Analyte Name
# TRITIUM                 13476      pCi/mL  1248.316406  3261.565925
# PH                      18517          pH     5.354886     1.529332
# SPECIFIC CONDUCTANCE    18276       uS/cm   425.754861   555.068915
# DEPTH_TO_WATER          20091          ft    46.814224    38.137888
# IODINE-129               5405       pCi/L    41.624339    92.511351
# URANIUM-238              5319       pCi/L    66.398114   169.240747
#
#                       Result min  Result 25%  Result 50%  Result 75%  \
# Analyte Name
# TRITIUM                   -0.628      25.300      193.00      934.00
# PH                         0.000       4.100        5.20        6.40
# SPECIFIC CONDUCTANCE       0.000      87.000      213.00      544.00
# DEPTH_TO_WATER             0.500      16.450       32.17       72.90
# IODINE-129              -356.900       0.996        9.37       45.10
# URANIUM-238               -2.650       0.062        0.64       43.75
#
#                       Result max
# Analyte Name
# TRITIUM                  44800.0
# PH                          12.7
# SPECIFIC CONDUCTANCE     10700.0
# DEPTH_TO_WATER             177.2
# IODINE-129                1620.0
# URANIUM-238               1810.0

# %% [markdown]
# ### Plotting functions

# %%
usage.get_FunctionDescription('plot_data')
# Out:
# plot_data (well_name, analyte_name, log_transform=True,
#      alpha=0, year_interval=2, plot_inline=True, save_dir='plot_data')
# Description:
#     Plot concentrations over time of a specified well and analyte with a smoothed curve on interpolated data points.
# Parameters:
#     well_name (string): name of the well to be processed
#     analyte_name (string): name of the analyte to be processed
#     log_transform (bool): choose whether or not the data should be transformed to log base 10 values
#     alpha (int): value between 0 and 10 for line smoothing
#     year_interval (int): plot by how many years to appear in the axis e.g.(1 = every year, 5 = every 5 years, ...)
#     plot_inline (bool): choose whether or not to show plot inline
#     save_dir (string): name of the directory you want to save the plot to

# %%
pylenm.plot_data(well_name= 'FSB 95DR', analyte_name='TRITIUM')
pylenm.plot_data(well_name= 'FSB 98C', analyte_name='SPECIFIC CONDUCTANCE', year_interval=5)

# %% [markdown]
# When using the interpolation functionality, a resampling frequency can be specifed. Correct inputs for the the frequency can be found in the function description.

# %%
usage.get_FunctionDescription('interpolate_well_data')
# Out:
# interpolate_well_data (well_name, analytes, frequency='2W')
# Description:
#     Resamples the data based on the frequency specified and interpolates the values of the analytes.
# Parameters:
#     well_name (string): name of the well to be processed
#     analytes (list of strings): list of analyte names to use
#     frequency (string): {‘D’, ‘W’, ‘M’, ‘Y’} frequency to interpolate.
#         See https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html for valid frequency inputs.
#         (e.g. ‘W’ = every week, ‘D ’= every day, ‘2W’ = every 2 weeks)

# %%
pylenm.interpolate_well_data(well_name='FSB 95DR',
                             analytes=['IODINE-129', 'TRITIUM', 'URANIUM-238'],
                             frequency='D')
# Out:
#                  IODINE-129       TRITIUM  URANIUM-238
# COLLECTION_DATE
# 1993-02-19       176.000000  23500.000000  1620.000000
# 1993-02-20       173.747105  23484.210526  1616.184211
# 1993-02-21       171.494211  23468.421053  1612.368421
# 1993-02-22       169.241316  23452.631579  1608.552632
# 1993-02-23       166.988421  23436.842105  1604.736842
# ...                     ...           ...          ...
# 2015-07-25       479.518519    244.339623   209.486772
# 2015-07-26       479.888889    244.754717   209.365079
# 2015-07-27       480.259259    245.169811   209.243386
# 2015-07-28       480.629630    245.584906   209.121693
# 2015-07-29       481.000000    246.000000   209.000000
#
# [8196 rows x 3 columns]

# %%
pylenm.interpolate_well_data(well_name='FSB 95DR',
                             analytes=['IODINE-129', 'TRITIUM', 'URANIUM-238'],
                             frequency='4M')
# Out:
#                  IODINE-129    TRITIUM  URANIUM-238
# COLLECTION_DATE
# 1993-02-28           176.00  23500.000       1620.0
# 1993-06-30             4.78  22300.000       1330.0
# 1993-10-31           206.00  18900.000       1100.0
# 1994-02-28           138.00  16500.000       1455.0
# 1994-06-30           172.50  16000.000       1517.5
# ...                     ...        ...          ...
# 2014-06-30           203.50    247.000        275.5
# 2014-10-31           244.00    147.575        255.0
# 2015-02-28           411.00    278.000        232.0
# 2015-06-30           446.00    202.000        220.5
# 2015-10-31           481.00    246.000        209.0
#
# [69 rows x 3 columns]

# %%
pylenm.plot_correlation_heatmap(well_name='FSB 95DR')

# %%
pylenm.plot_corr_by_well(well_name='FSB 95DR')
pylenm.plot_corr_by_well(well_name='FSB 95DR', interpolate=True, frequency='M')

# %%
pylenm.plot_corr_by_date('1993-02-21')

# %%
pylenm.plot_corr_by_year(2005)

# %%
pylenm.plot_MCL('FSB110D', 'TRITIUM', year_interval=4)
pylenm.plot_MCL('FSB 95DR', 'NITRATE-NITRITE AS NITROGEN')

# %%
pylenm.plot_PCA_by_date('1993-02-21')

# %%
pylenm.plot_PCA_by_year(2015, show_labels=False)
